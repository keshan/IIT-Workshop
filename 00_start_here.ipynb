# %% [markdown]
# # Beyond the Chatbot · Hands-on notebook kit
#
# The notebooks connect a small model to a larger software system. Start with one question in each: what changes, what evidence enters, and what code enforces the boundary?
#
# ## Choose the path
#
# | Notebook | You will investigate | What actually runs |
# | --- | --- | --- |
# | 01 Learning and tokens | Error, learned parameters, token sampling | Gradient descent and a tiny word-bigram model |
# | 02 Context and prompts | Input assembly, token budgets, checkpoints | Python context construction with labelled toy token counts |
# | 03 Retrieval and grounding | TF–IDF, cosine, source/access filtering | A real small lexical retriever; generation is separate |
# | 04 Tools, agents, harness | Tool validation, approvals, failure, stop conditions | Real Python tools on fictional in-memory data; scripted decisions |
# | 05 Optional local LLM | Real generation and structured proposals | Your explicitly enabled, already installed local model |
#
# The instructor will select workshop checkpoints. You do not need to finish every extension during the session. Each notebook is independent: there are no hidden helper files, API keys, or datasets to download.
#
# ## Working in a notebook
#
# - Python code runs in a **kernel**, which remembers variables between cells.
# - Click a cell and use **Shift+Enter** to run it.
# - A code cell marked `[*]` is still running. Wait, or use the stop/interrupt button.
# - Run from the top. After changing an earlier cell, rerun dependent cells.
# - Use **Kernel → Restart Kernel and Run All Cells** to check reproducibility.
# - Save your own copy before experimenting. Keep the originals for comparison.
# - An exercise with `None` prints a reminder. It is complete only after its checks print PASS.
#
# Notebook 05 stays disabled by default. It is optional, uses a local service, and makes no real bookings.

# %%
import sys
print("Python:", sys.version.split()[0])
assert sys.version_info >= (3, 10), "Use Python 3.10 or newer."
try:
    import matplotlib
    print("Matplotlib:", matplotlib.__version__)
    print("Setup ready. Open notebook 01.")
except ImportError:
    print("Matplotlib is missing. Follow README.md before the session.")
# No package installation or download runs automatically.

# %% [markdown]
# ## A small check before starting
#
# Predict the result, then run the cell. Change `pages` and run again. This is ordinary Python computation, not AI.

# %%
pages = 4
price_per_page = 3
print("Printing cost (fictional LKR):", pages * price_per_page)

# %% [markdown]
# ## If something goes wrong
#
# **NameError:** run earlier setup cells. **An assertion fails:** read the message, inspect the input, and correct your exercise. Do not delete the test. **A missing package:** follow the installation guide in README.md. **A stale or surprising result:** restart the kernel and run from the top.
#
# ## Your learning record
#
# For each experiment, write: my prediction, what happened, the explanation, and one case that might fail. The goal is to understand the boundaries of each component, not just produce a green test.
#
# Local setup instructions and the course-file map are in [README.md](README.md).
